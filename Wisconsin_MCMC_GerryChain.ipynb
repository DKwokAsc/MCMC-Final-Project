# %% [markdown]
# <a href="https://colab.research.google.com/github/DKwokAsc/MCMC-Final-Project/blob/main/Wisconsin_MCMC_GerryChain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Wisconsin MCMC GerryChain Partition and Elections**
#
# This file creates partitions and ensembles for Markov Chain, Partitions and Elections
#
#
# ---
#
#
# Requirements:
# - `wi_2024_gen_prec_graph.json` must already be downloaded and inputted in the default file folder. If not, see the instructions on `Wisconsin_SHP_File_Conversion.ipynb`

# %%
# Install gerrychain packages
# !pip install gerrychain[geo]
# Out:
# Collecting gerrychain[geo]
#   Downloading gerrychain-0.3.2-py2.py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from gerrychain[geo]) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from gerrychain[geo]) (1.16.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from gerrychain[geo]) (3.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from gerrychain[geo]) (3.10.0)
# Requirement already satisfied: shapely>=2.0.1 in /usr/local/lib/python3.12/dist-packages (from gerrychain[geo]) (2.1.2)
# Requirement already satisfied: geopandas>=0.12.2 in /usr/local/lib/python3.12/dist-packages (from gerrychain[geo]) (1.1.1)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.12/dist-packages (from geopandas>=0.12.2->gerrychain[geo]) (2.0.2)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from geopandas>=0.12.2->gerrychain[geo]) (0.11.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from geopandas>=0.12.2->gerrychain[geo]) (25.0)
# Requirement already satisfied: pyproj>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from geopandas>=0.12.2->gerrychain[geo]) (3.7.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->gerrychain[geo]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->gerrychain[geo]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->gerrychain[geo]) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->gerrychain[geo]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->gerrychain[geo]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->gerrychain[geo]) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->gerrychain[geo]) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->gerrychain[geo]) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->gerrychain[geo]) (3.2.5)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from pyogrio>=0.7.2->geopandas>=0.12.2->gerrychain[geo]) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->gerrychain[geo]) (1.17.0)
# Downloading gerrychain-0.3.2-py2.py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.9/87.9 kB 2.6 MB/s eta 0:00:00
# Installing collected packages: gerrychain
# Successfully installed gerrychain-0.3.2

# %%
# Install additional dependencies
# Credit to the GerryChain documentation & tutorial for providing many of the
# examples done in this demo
from gerrychain import Graph, Partition, MarkovChain, Election, metrics
from gerrychain.proposals import propose_random_flip,recom
from gerrychain.updaters import Tally, cut_edges
from gerrychain.constraints import Validator, single_flip_contiguous, contiguous, within_percent_of_ideal_population # used for validators
from gerrychain.accept import always_accept
from functools import partial

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import pickle

import random
random.seed(42)

# %% [markdown]
# #**Winconsin Election Addition**

# %%
# Remove empty row warnings (to decide later)
import warnings
warnings.filterwarnings("ignore")

# Initialize the graph for chains
graph = Graph.from_json("./wi_2024_gen_prec_graph.json")

# Create the election first to validate data
election = Election(
    "PRES24",
    {"Dem":"PREDEM24", "Rep":"PREREP24"}
)

# Create 3 plans: One for congressionalm one for state assembly, one for state district

cong_partition = Partition(
    graph,
    assignment="CONG_DIST",
    updaters={
        "population": Tally("PERSONS", alias="population"),
        "cut_edges": cut_edges,
        "PRES24": election
    }
)

state_assem_partition = Partition(
    graph,
    assignment="SLDL_DIST",
    updaters={
        "population": Tally("PERSONS", alias="population"),
        "cut_edges": cut_edges,
        "PRES24": election
    }
)

state_dist_partition = Partition(
    graph,
    assignment="SLDU_DIST",
    updaters={
        "population": Tally("PERSONS", alias="population"),
        "cut_edges": cut_edges,
        "PRES24": election
    }
)

# Prints output returns population info based on the plan chosen
def print_population(name, partition):
  print(f"\n{name} Plan Population:")
  for district, pop in partition["population"].items():
      print(f"  District {district}: {pop}")


# Sanity check
print_population("Congressional", cong_partition)
print_population("State Assembly", state_assem_partition)
print_population("State district", state_dist_partition)
# Out:
# Congressional Plan Population:
#   District 03: 736716.0
#   District 07: 736715.0
#   District 08: 736714.0
#   District 06: 736692.0
#   District 02: 736715.0
#   District 05: 736737.0
#   District 01: 736715.0
#   District 04: 736714.0
#
# State Assembly Plan Population:
#   District 72: 59742.0
#   District 57: 59642.0
#   District 41: 59672.0
#   District 39: 59796.0
#   District 71: 59463.0
#   District 74: 58968.0
#   District 73: 59853.0
#   District 67: 60062.0
#   District 88: 59855.0
#   District 89: 59697.0
#   District 02: 59983.0
#   District 01: 59444.0
#   District 90: 59551.0
#   District 04: 60096.0
#   District 05: 59076.0
#   District 06: 59188.0
#   District 29: 59983.0
#   District 75: 60058.0
#   District 03: 59173.0
#   District 27: 60058.0
def summarize_election(partition):
  # Create the election based on the selected map "partition"
  election_map = partition["PRES24"]
  # Compute the efficiency gap using metrics.efficiency_gap
  efficiency_gap = metrics.efficiency_gap(election_map)

  # Compute the number of districts won by republicans
  rep_wins = election_map.seats("Rep")

  return efficiency_gap, rep_wins

# Function: Printing function for election results
# Returns: Print desired output based on the selected map, its efficiency gap and seats taken
def print_results(name, efficiency_gap, districts_won):
  print(f"{name} Voting Results")
  print(f"Efficiency gap: {efficiency_gap:0.4f}")
  print(f"Districts won: {districts_won}")

eg_dem, rep_wins_dem = summarize_election(cong_partition)
print_results("Congressional Plan", eg_dem, rep_wins_dem)

eg_rep, rep_wins_rep = summarize_election(state_assem_partition)
print_results("State Assembly Plan", eg_rep, rep_wins_rep)

eg_comp, rep_wins_comp = summarize_election(state_dist_partition)
print_results("State District Plan", eg_rep, rep_wins_comp)
# Out:
# Congressional Plan Voting Results
# Efficiency gap: -0.2535
# Districts won: 6
# State Assembly Plan Voting Results
# Efficiency gap: -0.0261
# Districts won: 50
# State District Plan Voting Results
# Efficiency gap: -0.0261
# Districts won: 15

# %% [markdown]
# #**Create Mini Ensembles for all 3 Partitions**

# %%
# Number of plans
num_plans = 100
cong_ensemble = []

# Create the Markov chain
chain = MarkovChain(
    proposal= propose_random_flip,
    accept=always_accept,
    initial_state=cong_partition,
    total_steps=num_plans
)

# Generate plans
for step, partition in enumerate(chain):
    cong_ensemble.append(partition)
print(f"Generated {len(cong_ensemble)} plans.")
# Out:
# Generated 100 plans.

# %%
# Use the same partition from the all favoring plans (In first cell already)

# Intialize the target population
# We need total population (dictionnary) and the number of districts (list) to find ideal population for a single district
tot_pop = sum(cong_partition["population"].values())
print(tot_pop)

tot_districts = len(cong_partition.parts)

target_pop = tot_pop/tot_districts
print(target_pop)

# Add the ReCom proposal method
proposal = partial(
    recom,
    pop_col="PERSONS",
    pop_target=target_pop,
    epsilon=0.01,
    node_repeats=2
)

# Make every plan follow these constraints

constraints = [within_percent_of_ideal_population(cong_partition, 0.01)]
# Add the Markov Chain
chain = MarkovChain(proposal=proposal, constraints=constraints,accept=always_accept, initial_state=cong_partition, total_steps=100)

# Sanity check
for (i,part) in enumerate(chain):
  print(f"Step {i} Rep vote share for dist 1: "
    f"{part['PRES24'].percents('Rep')[1]:0.4f}")
# Out:
# 5893718.0
# 736714.75
# Step 0 Rep vote share for dist 1: 0.6142
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/networkx/classes/graph.py in add_nodes_from(self, nodes_for_adding, **attr)
#     635             try:
# --> 636                 newnode = n not in self._node
#     637                 newdict = attr
#
# TypeError: unhashable type: 'dict'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-972998216.py in <cell line: 0>()
#      27
#      28 # Sanity check
# ---> 29 for (i,part) in enumerate(chain):
#      30   print(f"Step {i} Rep vote share for dist 1: "
#      31     f"{part['PRES24'].percents('Rep')[1]:0.4f}")
#
# /usr/local/lib/python3.12/dist-packages/gerrychain/chain.py in __next__(self)
#     184
#     185         while self.counter < self.total_steps:
# --> 186             proposed_next_state = self.proposal(self.state)
#     187             # Erase the parent of the parent, to avoid memory leak
#     188             if self.state is not None:
#
# /usr/local/lib/python3.12/dist-packages/gerrychain/proposals/tree_proposals.py in recom(partition, pop_col, pop_target, epsilon, node_repeats, region_surcharge, method)
#     120             )
#     121
# --> 122             flips = epsilon_tree_bipartition(
#     123                 subgraph.graph,
#     124                 parts_to_merge,
#
# /usr/local/lib/python3.12/dist-packages/gerrychain/tree.py in epsilon_tree_bipartition(graph, parts, pop_target, pop_col, epsilon, node_repeats, method)
#     933     check_pop = lambda x: lb_pop <= x <= ub_pop
#     934
# --> 935     nodes = method(
#     936         graph.subgraph(remaining_nodes),
#     937         pop_col=pop_col,
#
# /usr/local/lib/python3.12/dist-packages/gerrychain/tree.py in bipartition_tree(graph, pop_col, pop_target, epsilon, node_repeats, spanning_tree, spanning_tree_fn, region_surcharge, balance_edge_fn, one_sided_cut, choice, max_attempts, warn_attempts, allow_pair_reselection, cut_choice)
#     679     while max_attempts is None or attempts < max_attempts:
#     680         if restarts == node_repeats:
# --> 681             spanning_tree = spanning_tree_fn(graph)
#     682             restarts = 0
#     683         h = PopulatedGraph(spanning_tree, populations, pop_target, epsilon)
#
# /usr/local/lib/python3.12/dist-packages/gerrychain/tree.py in random_spanning_tree(graph, region_surcharge)
#      89         graph.edges[edge]["random_weight"] = weight
#      90
# ---> 91     spanning_tree = tree.minimum_spanning_tree(
#      92         graph, algorithm="kruskal", weight="random_weight"
#      93     )
#
# /usr/local/lib/python3.12/dist-packages/networkx/utils/decorators.py in argmap_minimum_spanning_tree_22(G, weight, algorithm, ignore_nan, backend, **backend_kwargs)
#       1 import bz2
#       2 import collections
# ----> 3 import gzip
#       4 import inspect
#       5 import itertools
#
# /usr/local/lib/python3.12/dist-packages/networkx/utils/backends.py in _call_if_any_backends_installed(self, backend, *args, **kwargs)
#     927                 if not graph_backend_names or graph_backend_names == {backend_name}:
#     928                     if self._can_backend_run(backend_name, args, kwargs):
# --> 929                         return self._call_with_backend(backend_name, args, kwargs)
#     930                 elif self._can_convert(
#     931                     backend_name, graph_backend_names
#
# /usr/local/lib/python3.12/dist-packages/networkx/utils/backends.py in _call_with_backend(self, backend_name, args, kwargs, extra_message)
#    1461         """Call this dispatchable function with a backend without converting inputs."""
#    1462         if backend_name == "networkx":
# -> 1463             return self.orig_func(*args, **kwargs)
#    1464         backend = _load_backend(backend_name)
#    1465         _logger.debug(
#
# /usr/local/lib/python3.12/dist-packages/networkx/algorithms/tree/mst.py in minimum_spanning_tree(G, weight, algorithm, ignore_nan)
#     611     T = G.__class__()  # Same graph class as G
#     612     T.graph.update(G.graph)
# --> 613     T.add_nodes_from(G.nodes.items())
#     614     T.add_edges_from(edges)
#     615     return T
#
# /usr/local/lib/python3.12/dist-packages/networkx/classes/graph.py in add_nodes_from(self, nodes_for_adding, **attr)
#     639                 n, ndict = n
#     640                 newnode = n not in self._node
# --> 641                 newdict = attr.copy()
#     642                 newdict.update(ndict)
#     643             if newnode:
#
# KeyboardInterrupt:
